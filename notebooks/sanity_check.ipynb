# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from models.loader import process_image, build_transform

out = process_image("test.png", build_transform())
print(out.shape)
print(out.dtype)
print(out.device)
print(out)
print("mean of all pixels:", out.mean().item())
print("std of all pixels:", out.std().item())
# Out:
# torch.Size([1, 3, 256, 256])
# torch.float32
# cpu
# tensor([[[[ 0.4166,  0.3823,  0.4166,  ...,  0.9303,  1.2899,  1.5639],
#           [ 0.4166,  0.3823,  0.3994,  ...,  1.5639,  1.8037,  1.7009],
#           [ 0.3994,  0.3823,  0.3823,  ...,  1.5810,  0.8618,  0.5022],
#           ...,
#           [ 1.0159,  0.9988,  1.0331,  ...,  0.8618,  0.9303,  0.8276],
#           [ 1.1187,  0.9817,  0.8789,  ...,  0.8618,  0.8961,  0.6906],
#           [ 1.0159,  0.9132,  0.9132,  ...,  0.8618,  0.9646,  0.8104]],
#
#          [[ 1.0980,  1.0805,  1.0805,  ...,  1.9384,  2.1134,  2.2535],
#           [ 1.0980,  1.0805,  1.0630,  ...,  2.2710,  2.3585,  2.3936],
#           [ 1.0455,  1.0280,  1.0455,  ...,  2.2185,  1.9209,  1.6232],
#           ...,
#           [ 1.4132,  1.4307,  1.4482,  ...,  1.2906,  1.3431,  1.2731],
#           [ 1.5882,  1.3957,  1.2906,  ...,  1.3256,  1.3431,  1.1856],
#           [ 1.5182,  1.4482,  1.4307,  ...,  1.3431,  1.4132,  1.3256]],
#
# ...
